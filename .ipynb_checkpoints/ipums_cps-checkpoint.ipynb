# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import scipy.stats as stats
import statsmodels.api as sm
from statsmodels.formula.api import ols

# %%
raw = pd.read_csv('cps_00008.csv')

# %%
raw.isnull().sum(axis = 0)
# Out:
# YEAR             0
# SERIAL           0
# MONTH            0
# CPSID            0
# ASECFLAG         0
# ASECWTH          0
# REGION           0
# METAREA          0
# PERNUM           0
# CPSIDP           0
# ASECWT           0
# AGE              0
# SEX              0
# EDUC             0
# OCCLY            0
# INDLY            0
# WKXPNS      180084
# INCTOT           0
# INCWAGE          0
# MIGSTA1          0
# WHYMOVE          0
# dtype: int64

# %%
raw.columns
# Out:
# Index(['YEAR', 'SERIAL', 'MONTH', 'CPSID', 'ASECFLAG', 'ASECWTH', 'REGION',
#        'METAREA', 'PERNUM', 'CPSIDP', 'ASECWT', 'AGE', 'SEX', 'EDUC', 'OCCLY',
#        'INDLY', 'WKXPNS', 'INCTOT', 'INCWAGE', 'MIGSTA1', 'WHYMOVE'],
#       dtype='object')

# %%
r2016 = raw.loc[raw['YEAR']==2016]
r2017 = raw.loc[raw['YEAR']==2017]
r2018 = raw.loc[raw['YEAR']==2018]

print(raw.shape)
raw.head()
# Out:
# (551485, 21)
#    YEAR  SERIAL  MONTH           CPSID  ASECFLAG  ASECWTH  REGION  METAREA  \
# 0  2016       2      3  20141202933700         1  1132.05      11     9998
# 1  2016       7      3  20151202935900         1  1077.54      11     9998
# 2  2016       7      3  20151202935900         1  1077.54      11     9998
# 3  2016       8      3  20160202937400         1  1151.49      11     9998
# 4  2016       9      3  20160102910900         1   705.00      11     9998
#
#    PERNUM          CPSIDP   ...     AGE  SEX  EDUC  OCCLY  INDLY  WKXPNS  \
# 0       1  20141202933701   ...      79    2    30      0      0  9999.0
# 1       1  20151202935901   ...      60    2    50      0      0  9999.0
# 2       2  20151202935902   ...      59    1    81      0      0  9999.0
# 3       1  20160202937401   ...      69    1    81      0      0  9999.0
# 4       1  20160102910901   ...      24    1    73   9140   6190  1471.0
#
#    INCTOT  INCWAGE  MIGSTA1  WHYMOVE
# 0   13309        0       99        0
# 1   11681        0       99        0
# 2   17615        0       99        0
# 3   24099        0       99        0
# 4    6300     6000       99        0
#
# [5 rows x 21 columns]

# %%
raw_filtered = raw.loc[raw['INCTOT'] != 0]
raw_filtered = raw_filtered.loc[raw['INCTOT'] != 99999999.0]
raw_filtered = raw_filtered.loc[raw['INCTOT'] != 99999998.0]
raw_filtered = raw_filtered.loc[raw['AGE'] <=80]

# %%
raw2016_filtered = raw.loc[raw['INCTOT'] != 0]
raw2016_filtered = raw2016_filtered.loc[raw['INCTOT'] != 99999999.0]
raw2016_filtered = raw2016_filtered.loc[raw['INCTOT'] != 99999998.0]
raw2016_filtered = raw2016_filtered.loc[raw['AGE'] <=80]

# %%
raw_filtered.head()
# Out:
#    YEAR  SERIAL  MONTH           CPSID  ASECFLAG  ASECWTH  REGION  METAREA  \
# 0  2016       2      3  20141202933700         1  1132.05      11     9998
# 1  2016       7      3  20151202935900         1  1077.54      11     9998
# 2  2016       7      3  20151202935900         1  1077.54      11     9998
# 3  2016       8      3  20160202937400         1  1151.49      11     9998
# 4  2016       9      3  20160102910900         1   705.00      11     9998
#
#    PERNUM          CPSIDP   ...     AGE  SEX  EDUC  OCCLY  INDLY  WKXPNS  \
# 0       1  20141202933701   ...      79    2    30      0      0  9999.0
# 1       1  20151202935901   ...      60    2    50      0      0  9999.0
# 2       2  20151202935902   ...      59    1    81      0      0  9999.0
# 3       1  20160202937401   ...      69    1    81      0      0  9999.0
# 4       1  20160102910901   ...      24    1    73   9140   6190  1471.0
#
#    INCTOT  INCWAGE  MIGSTA1  WHYMOVE
# 0   13309        0       99        0
# 1   11681        0       99        0
# 2   17615        0       99        0
# 3   24099        0       99        0
# 4    6300     6000       99        0
#
# [5 rows x 21 columns]

# %%
raw_tech = raw_filtered.loc[raw_filtered['OCCLY'] >= 1000]
raw_tech = raw_tech.loc[raw_filtered['OCCLY'] <= 1107]

# %%
raw_tech
# Out:
#         YEAR  SERIAL  MONTH           CPSID  ASECFLAG  ASECWTH  REGION  \
# 314     2016     321      3  20160102916200         1  1446.40      11
# 360     2016     349      3  20160102923400         1  1443.55      11
# 400     2016     371      3  20160202938800         1  1313.19      11
# 439     2016     401      3               0         1   985.99      11
# 759     2016     578      3               0         1   572.44      11
# 891     2016     665      3  20160302962900         1   666.53      11
# 1113    2016     791      3               0         1   646.40      11
# 1191    2016     838      3  20160202909100         1  1046.33      11
# 1203    2016     843      3  20150102908400         1   650.44      11
# 1453    2016    1089      3  20150104253700         1   476.23      11
# 1620    2016    1209      3  20150204222400         1   384.05      11
# 1637    2016    1221      3  20141204228600         1   754.20      11
# 1657    2016    1233      3  20160304172900         1   436.53      11
# 1757    2016    1275      3  20160104167500         1   728.42      11
# 1911    2016    1374      3               0         1   396.97      11
# 1925    2016    1377      3               0         1   405.13      11
# 1977    2016    1427      3  20150304222600         1   797.01      11
# 2039    2016    1460      3  20160204120700         1   375.44      11
# 2076    2016    1476      3  20141204176800         1   749.98      11
# 2209    2016    1549      3  20150204187400         1   395.49      11
# 2227    2016    1556      3  20160304113300         1   779.15      11
# 2282    2016    1577      3  20160204126300         1   742.19      11
# 2302    2016    1594      3  20160204117200         1   433.22      11
# 2337    2016    1607      3  20160304134600         1   765.62      11
# 2338    2016    1607      3  20160304134600         1   765.62      11
# 2397    2016    1653      3               0         1   443.32      11
# 2445    2016    1673      3               0         1   462.46      11
# 2452    2016    1675      3               0         1   608.91      11
# 2513    2016    1693      3               0         1   406.53      11
# 2566    2016    1706      3  20150304151300         1   864.20      11
# ...      ...     ...    ...             ...       ...      ...     ...
# 549434  2018   91221      3  20161201949500         1   428.29      42
# 549457  2018   91239      3  20171201959300         1   409.16      42
# 549481  2018   91250      3  20170102000900         1   384.65      42
# 549532  2018   91277      3  20180301950500         1   522.62      42
# 549643  2018   91348      3  20180101968100         1   377.34      42
# 549666  2018   91360      3  20180101907100         1   697.30      42
# 549667  2018   91360      3  20180101907100         1   697.30      42
# 549674  2018   91363      3  20161201966600         1   347.52      42
# 549675  2018   91363      3  20161201966600         1   347.52      42
# 549718  2018   91388      3  20170301951600         1   478.59      42
# 549786  2018   91419      3  20180101917200         1   392.47      42
# 549959  2018   91491      3  20170501959500         1   599.09      42
# 550131  2018   91566      3  20180101928400         1   789.82      42
# 550132  2018   91566      3  20180101928400         1   789.82      42
# 550139  2018   91570      3  20180301924100         1   442.35      42
# 550155  2018   91577      3  20180201920900         1   869.50      42
# 551168   3680     NaN   90037    90000       99        0
# 551170   7380     NaN   74245    72000       99        0
# 551249   6680     NaN  104599   100000       99        0
# 551300   9590     NaN  159106   135000       99        0
# 551361   6680     NaN   43081    43000       99        0
# 551433   7380     NaN   23002    23000       99        0
# 551471   9590     NaN   96900    75500       99        0
#
# [7242 rows x 21 columns]

# %%
plt.scatter(raw_filtered['AGE'], raw_filtered['INCTOT'])
plt.title('AGE INCOME all')

plt.show()
#all age income for all 3 yrs

# %%
plt.scatter(raw2016_filtered['AGE'], raw2016_filtered['INCTOT'])
plt.title('AGE INCOME all')

plt.show()
#all age income 2016

# %%
def filt_metro(metarea, data):
    return data.loc[data['METAREA']==metarea]

# %%
sns.distplot(filt_metro(5606, raw_filtered)['INCTOT']) #all occupation

# %%
plt.scatter(filt_metro(5606, raw_filtered)['AGE'], filt_metro(5606, raw_filtered)['INCTOT'])
plt.title('METAREA 5606 Income')

m, b, r, p, std_err = stats.linregress(filt_metro(5606, raw_filtered)['AGE'], filt_metro(5606, raw_filtered)['INCTOT'])
x = np.linspace(15,80,100)
y = m*x+b
plt.plot(x, y, '-r')
print(f'y={m}x+{b}')

#all occupation in NYC area
# Out:
# y=237.98074269113496x+44179.446209894944

# %%
f = 'INCTOT~AGE'
model = ols(formula=f, data=filt_metro(5606, raw_filtered)).fit()
model.summary()
#NYC area all occ
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 INCTOT   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                  0.002
# Method:                 Least Squares   F-statistic:                     36.90
# Date:                Wed, 06 Mar 2019   Prob (F-statistic):           1.27e-09
# Time:                        14:49:50   Log-Likelihood:            -2.0065e+05
# No. Observations:               15759   AIC:                         4.013e+05
# Df Residuals:                   15757   BIC:                         4.013e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   4.418e+04   1928.974     22.903      0.000    4.04e+04     4.8e+04
# AGE          237.9807     39.175      6.075      0.000     161.194     314.767
# ==============================================================================
# Omnibus:                    19117.236   Durbin-Watson:                   1.817
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          2963428.481
# Skew:                           6.517   Prob(JB):                         0.00
# Kurtosis:                      68.903   Cond. No.                         146.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
filt_metro(5606, raw_tech).describe()
#tech NYC area
# Out:
#               YEAR        SERIAL  MONTH         CPSID  ASECFLAG      ASECWTH  \
# count   409.000000    409.000000  409.0  4.090000e+02     409.0   409.000000
# mean   2016.916870  10664.562347    3.0  1.232482e+13       1.0  2492.117995
# std       0.806186   1370.676910    0.0  9.841035e+12       0.0   882.904832
# min    2016.000000   7756.000000    3.0  0.000000e+00       1.0  1463.120000
# 25%    2016.000000   9484.000000    3.0  0.000000e+00       1.0  1880.020000
# 50%    2017.000000  10970.000000    3.0  2.015120e+13       1.0  2176.710000
# 75%    2018.000000  11897.000000    3.0  2.017010e+13       1.0  2815.050000
# max    2018.000000  12819.000000    3.0  2.018030e+13       1.0  5982.980000
#
#        REGION  METAREA      PERNUM        CPSIDP     ...             AGE  \
# count   409.0    409.0  409.000000  4.090000e+02     ...      409.000000
# mean     12.0   5606.0    1.601467  1.232482e+13     ...       41.156479
# std       0.0      0.0    0.904833  9.841035e+12     ...       12.222807
# min      12.0   5606.0    1.000000  0.000000e+00     ...       17.000000
# 25%      12.0   5606.0    1.000000  0.000000e+00     ...       32.000000
# 50%      12.0   5606.0    1.000000  2.015120e+13     ...       40.000000
# 75%      12.0   5606.0    2.000000  2.017010e+13     ...       50.000000
# max      12.0   5606.0    7.000000  2.018030e+13     ...       80.000000
#
#               SEX        EDUC        OCCLY        INDLY       WKXPNS  \
# count  409.000000  409.000000   409.000000   409.000000   292.000000
# mean     1.232274  109.699267  1040.877751  6886.728606  1791.232877
# std      0.422800   15.633361    38.097974  1547.207436   312.213097
# min      1.000000   20.000000  1005.000000   570.000000   171.000000
# 25%      1.000000  111.000000  1010.000000  6870.000000  1779.000000
# 50%      1.000000  111.000000  1020.000000  7380.000000  1779.000000
# 75%      1.000000  123.000000  1050.000000  7380.000000  2000.000000
# max      2.000000  125.000000  1107.000000  9590.000000  2000.000000
#
#               INCTOT        INCWAGE     MIGSTA1     WHYMOVE
# count     409.000000     409.000000  409.000000  409.000000
# mean   101330.349633   93075.652812   91.420538    0.938875
# std     67826.404184   64146.149916   20.936860    2.865221
# min       500.000000       0.000000    9.000000    0.000000
# 25%     60000.000000   55000.000000   99.000000    0.000000
# 50%     86000.000000   80000.000000   99.000000    0.000000
# 75%    126101.000000  120000.000000   99.000000    0.000000
# max    415366.000000  410000.000000   99.000000   17.000000
#
# [8 rows x 21 columns]

# %%
sns.distplot(filt_metro(5606, raw_tech)['INCTOT'])
#tech nyc

# %%
sns.distplot(filt_metro(4484, raw_tech)['INCTOT'])
#tech LA

# %%
raw_filtered.describe()
# Out:
#                 YEAR         SERIAL     MONTH         CPSID  ASECFLAG  \
# count  366506.000000  366506.000000  366506.0  3.665060e+05  366506.0
# mean     2016.993574   47907.225077       3.0  1.360366e+13       1.0
# std         0.814096   27478.220978       0.0  9.446463e+12       0.0
# min      2016.000000       2.000000       3.0  0.000000e+00       1.0
# 25%      2016.000000   23797.000000       3.0  0.000000e+00       1.0
# 50%      2017.000000   48054.000000       3.0  2.016010e+13       1.0
# 75%      2018.000000   72277.000000       3.0  2.017011e+13       1.0
# max      2018.000000   95006.000000       3.0  2.018031e+13       1.0
#
#              ASECWTH         REGION        METAREA         PERNUM  \
# count  366506.000000  366506.000000  366506.000000  366506.000000
# mean     1784.821819      29.388015    5944.418498       1.715792
# std      1091.203584      10.352502    3217.220791       1.003194
# min        93.240000      11.000000      60.000000       1.000000
# 25%       871.647500      21.000000    3291.000000       1.000000
# 50%      1705.440000      31.000000    5960.000000       1.000000
# 75%      2340.540000      41.000000    9240.000000       2.000000
# max      9027.360000      42.000000    9998.000000      16.000000
#
#              CPSIDP      ...                  AGE            SEX  \
# count  3.665060e+05      ...        366506.000000  366506.000000
# mean   1.360366e+13      ...            46.056968       1.507869
# std    9.446463e+12      ...            17.094314       0.499939
# min    0.000000e+00      ...            15.000000       1.000000
# 25%    0.000000e+00      ...            32.000000       1.000000
# 50%    2.016010e+13      ...            45.000000       2.000000
# 75%    2.017011e+13      ...            59.000000       2.000000
# max    2.018031e+13      ...            80.000000       2.000000
#
#                 EDUC          OCCLY          INDLY         WKXPNS  \
# count  366506.000000  366506.000000  366506.000000  246225.000000
# mean       86.362810    3118.177206    4726.790475    3899.193798
# std        24.418379    2889.925265    3608.591704    3671.408067
# min         2.000000       0.000000       0.000000       0.000000
# 25%        73.000000       0.000000       0.000000    1779.000000
# 50%        81.000000    3060.000000    6070.000000    2000.000000
# 75%       111.000000    4965.000000    7970.000000    9999.000000
# max       125.000000    9840.000000    9890.000000    9999.000000
#
#              INCTOT       INCWAGE        MIGSTA1        WHYMOVE
# count  3.665060e+05  3.665060e+05  366506.000000  366506.000000
# mean   4.653386e+04  3.606962e+04      92.634882       0.722073
# std    6.590772e+04  6.195771e+04      20.858423       2.702351
# min   -1.645800e+04  0.000000e+00       1.000000       0.000000
# 25%    1.406000e+04  0.000000e+00      99.000000       0.000000
# 50%    3.020500e+04  2.200000e+04      99.000000       0.000000
# 75%    5.817000e+04  5.000000e+04      99.000000       0.000000
# max    1.731899e+06  1.609999e+06      99.000000      19.000000
#
# [8 rows x 21 columns]

# %%
def var_frame(var, data):
    new = pd.concat([data['YEAR'],data[var],data['INCTOT']], ignore_index=True,axis=1)  
    new.columns = ['YEAR',var, 'INCTOT']
    return new

# %%
var_frame('EDUC', raw_filtered)
# Out:
#         YEAR  EDUC  INCTOT
# 0       2016    30   13309
# 1       2016    50   11681
# 2       2016    81   17615
# 3       2016    81   24099
# 4       2016    73    6300
# 6       2016    73    8796
# 8       2016    81   17786
# 9       2016    30    4561
# 10      2016    30   12841
# 11      2016    50   19930
# 12      2016    40   24523
# 13      2016    50   44779
# 14      2016    73    7251
# 15      2016    81   40800
# 16      2016   111   50072
# 17      2016    81   12000
# 18      2016    73   16000
# 22      2016    73   17796
# 24      2016   125   22859
# 25      2016    73     460
# 26      2016    73   18326
# 27      2016    60    3923
# 29      2016    73  102183
# 30      2016    73   32539
# 31      2016    91   61066
# 32      2016    73   25404
# 33      2016    73   66219
# 34      2016    81   40000
# 35      2016    73    8857
# 36      2016    73   16658
# ...      ...   ...     ...
# 551444  2018    81   14010
# 551445  2018    81   33002
# 551448  2018    91   69051
# 551452  2018    73   16859
# 551454  2018   111    8802
# 551456  2018    73   19005
# 551457  2018    73   47577
# 551458  2018   111   79930
# 551459  2018   111   55014
# 551460  2018   123   40003
# 551461  2018    73   24004
# 551462  2018    81   40018
# 551463  2018   111   96500
# 551464  2018    73   23490
# 551466  2018    73   25000
# 551467  2018    81   20000
# 551468  2018    73   23044
# 551469  2018    91   17006
# 551470  2018   111   93978
# 551471  2018   111   96900
# 551473  2018    81   42000
# 551474  2018   111   21556
# 551475  2018    81   27815
# 551476  2018   111   20016
# 551477  2018   111   40003
# 551478  2018    50      12
# 551479  2018    91   13390
# 551480  2018    92   24158
# 551481  2018    81   24026
# 551482  2018    81   11352
#
# [366506 rows x 3 columns]

# %%
def plotting(var, data):
    plt.scatter(data[var], data['INCTOT'])
    plt.show()
    sns.distplot(data[var])
    return plt.show()

# %%
plotting('AGE', raw_filtered)

# %%
overview = raw_filtered.drop(['ASECFLAG', 'SERIAL', 'CPSID', 'ASECWT', 'ASECWTH', 'CPSIDP', 'MONTH', 'SERIAL'], axis =1)

raw_filtered.hist(figsize=(16, 20), bins=50, xlabelsize=8, ylabelsize=8)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1cf44d7240>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1cfc0195f8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1cfbf8ed30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1d14a89278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1d14a7f7f0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1d14a71d68>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1d14a1a278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1d14a3a828>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1d14a3a860>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1d14a0a320>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1d149b0898>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1d14958e10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1d149873c8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1d14931940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1d0c3cfa90>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1d148e2048>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1d1490a5c0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1d148b3b38>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1d148650f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1d1488c668>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1d14832be0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1d147e4198>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1d1480b710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1d147b3c88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1d14765240>]],
#       dtype=object)
